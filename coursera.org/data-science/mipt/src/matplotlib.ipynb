# %%
# чтобы все графики отображались в нуотбуке
# %matplotlib inline

# %%
from matplotlib import pylab as plt
import numpy as np

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.show()

# %%
x = np.arange(-10, 10, 2)
y = x ** 3
plt.plot(x, y)
plt.show()
